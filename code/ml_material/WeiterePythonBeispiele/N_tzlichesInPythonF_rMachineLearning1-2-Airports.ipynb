# %%
import pandas as pd

df = pd.read_csv("./airfields.csv", sep=",")

# %%
df.head()
# Out:
#   ident           type                                name elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport           11
# 1  00AA  small_airport                Aero B Ranch Airport         3435
# 2  00AK  small_airport                        Lowell Field          450
# 3  00AL  small_airport                        Epps Airpark          820
# 4  00AR         closed  Newport Hospital & Clinic Heliport          237
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0       NaN          US      US-PA      Bensalem      00A       NaN
# 1       NaN          US      US-KS         Leoti     00AA       NaN
# 2       NaN          US      US-AK  Anchor Point     00AK       NaN
# 3       NaN          US      US-AL       Harvest     00AL       NaN
# 4       NaN          US      US-AR       Newport      NaN       NaN
#
#   local_code         coordinateL         coordinateB   q   z
# 0        00A  -74.93360137939453      40.07080078125 NaN NaN
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of          ident            type                                name  \
# 0          00A        heliport                   Total Rf Heliport
# 1         00AA   small_airport                Aero B Ranch Airport
# 2         00AK   small_airport                        Lowell Field
# 3         00AL   small_airport                        Epps Airpark
# 4         00AR          closed  Newport Hospital & Clinic Heliport
# ...        ...             ...                                 ...
# 57416     ZYYK  medium_airport               Yingkou Lanqi Airport
# 57417     ZYYY  medium_airport             Shenyang Dongta Airport
# 57418  ZZ-0001        heliport                     Sealand Helipad
# 57419  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 57420     ZZZZ   small_airport             Satsuma IÅjima Airport
#
#       elevation_ft continent iso_country iso_region      municipality  \
# ...

# %%
df["continent"].unique()
# Out:
# array([nan, 'OC', '890', '720', '983', '926', '4935', '95', '4115',
#        '1020', '3520', '15', '175', '533', '706', '3900', 'AF', 'AN',
#        'EU', 'AS', 'SA', '340', '986', '164', '650', '289', '200', '807',
#        '53', '92', '84', '243', '229', '14', '174', '88', '42', '286',
#        '242', '1290', '281', '1698', '560', '610', '2124', '589', '126',
#        '206', '77', '1060', '33', '4157', '1270', '3000', '130', '938',
#        '1047', '750', '6406', ' South America Airport', '1000', '1110',
#        '1041', ' REWA', ' Yemen', '23', '889', '558', '850', '548', '18',
#        '5001'], dtype=object)

# %%
df["iso_country"].unique()
# Out:
# array(['US', 'PR', 'MH', nan, 'MP', 'GU', 'SO', 'AQ', 'GB', 'PG', 'AD',
#        'SD', 'SA', 'AE', 'SS', 'ES', 'CN', 'AF', 'LK', 'SB', 'CO', 'AU',
#        'MG', 'TD', 'AL', 'XK', 'AM', 'MX', 'MZ', 'PW', 'NR', 'AO', 'AR',
#        'AS', 'AT', 'OC', 'GA', 'AZ', 'BA', 'BE', 'DE', 'BF', 'BG', 'GL',
#        'BH', 'BI', 'IS', 'BJ', 'OM', 'BM', 'KE', 'PH', 'BO', 'BR', 'BS',
#        'CV', 'BW', 'FJ', 'BY', 'UA', 'LR', 'BZ', 'CA', 'CD', 'CF', 'CG',
#        'MR', 'CH', 'CL', 'CM', 'CR', 'CU', 'CY', 'CZ', 'EU', 'SK', 'PA',
#        'DZ', 'ID', 'GH', 'RU', 'CI', 'DK', 'NG', 'DO', 'NE', 'HR', 'TN',
#        'TG', 'EC', 'EE', 'FI', 'EG', 'GG', 'JE', 'IM', 'FK', 'EH', 'NL',
#        'IE', 'FO', 'LU', 'GT', 'NO', 'PL', 'ER', 'MN', 'PT', 'SE', 'ET',
#        'LV', 'LT', 'ZA', 'SZ', 'GQ', 'SH', 'MU', 'IO', 'ZM', 'FM', 'KM',
#        'YT', 'RE', 'TF', 'ST', 'FR', 'SC', 'ZW', 'MW', 'LS', 'ML', 'GM',
#        'GE', 'GF', 'SL', 'GW', 'MA', 'GN', 'SN', 'GR', 'TZ', 'GY', 'SR',
# ...

# %%
df["type"].unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
x = df["local_code"].values
x[40000]
# Out:
# 'MDO'

# %%
de = df[df['iso_country']=='DE' ]
de
# Out:
#          ident           type  \
# 12193      BER         closed
# 17671  DE-0001       heliport
# 17672  DE-0002         closed
# 17673  DE-0003         closed
# 17674  DE-0004  small_airport
# ...        ...            ...
# 20430     ETWM  small_airport
# 23882      GWW         closed
# 41151     RHST  small_airport
# 54324      WID         closed
# 54940     XMUC         closed
#
#                                                    name elevation_ft  \
# 12193                 Berlin Brandenburg Airport (U.C.)          157
# 17671                   Klinikum am Plattenwald Helipad          NaN
# 17672  Ahlhorn Highway Strip Autobahn-Notlandeplatz NLP          NaN
# 17673                            August-Euler Flugplatz          NaN
# 17674                                 Flugplatz Gransee          164
# ...                                                 ...          ...
# 20430                                   Meppen Air Base          NaN
# ...

# %%
fp = de.query("(gps_code=='EDNG') or (gps_code=='EDMB')")
fp
# Out:
#       ident           type                         name elevation_ft  \
# 18771  EDMB  small_airport  Biberach a.d. RiÃ Airfield         1903
# 18799  EDNG  small_airport        Giengen/Brenz Airport         1696
#
#       continent iso_country iso_region          municipality gps_code  \
# 18771        EU          DE      DE-BW  Biberach an der RiÃ     EDMB
# 18799        EU          DE      DE-BW  Giengen an der Brenz     EDNG
#
#       iata_code local_code    coordinateL     coordinateB   q   z
# 18771       NaN        NaN       9.762778       48.111111 NaN NaN
# 18799       NaN        NaN  10.2163887024   48.6341667175 NaN NaN

# %%
import numpy as np
col = np.arange(df.count()['ident'])
df["color"] = np.where(df["type"] == "small_airport",['yellow'],['black'])
df["color"] = np.where(df["type"] == "medium_airport",['orange'],['black'])
df["color"] = np.where(df["type"] == "large_airport",['red'], ['black'])
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize = (20, 15))
plt.scatter(pd.to_numeric(df["coordinateL"], errors='coerce'),
            pd.to_numeric(df["coordinateB"], errors='coerce'), 
            c=df["color"], cmap='viridis', s=0.5)

# %%
import numpy as np
col = np.arange(de.count()['ident'])

# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 10))
plt.scatter(pd.to_numeric(de["coordinateL"], errors='coerce'),
            pd.to_numeric(de["coordinateB"], errors='coerce'), 
            c=col, cmap='viridis', s=10)
