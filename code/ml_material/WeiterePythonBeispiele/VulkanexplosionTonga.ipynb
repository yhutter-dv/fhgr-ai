# %% [markdown]
# # Explosion des Hunga Tonga-Hunga Ha'apai
# ### 1. Ausbruch: 15.01.2022 04:20Z - Peek um 19:36Z
# #### dt = 15.25h
# ### 2. Ausbuch: 16:01.2022 22:10Z - Peek um 13:20-13:25Z -> 14:20-MEZ

# %%
import pandas as pd
df = pd.read_csv("vulkanexplosion.csv")
df.head()
# Out:
#         id station  temperature     QFE      QNH  dewpoint  ceiling  humidity  \
# 0  4064995    EDNG        -4.61  969.12  1030.43     -4.86  1893.96     98.11
# 1  4064996    EDNG        -4.70  969.11  1030.42     -4.96  1896.04     98.07
# 2  4064997    EDNG        -4.72  969.06  1030.36     -4.98  1896.02     98.07
# 3  4064998    EDNG        -4.73  969.03  1030.33     -4.99  1896.01     98.07
# 4  4064999    EDNG        -4.73  969.04  1030.34     -4.99  1896.01     98.07
#
#             createTime
# 0  2022-01-15 00:00:32
# 1  2022-01-15 00:02:05
# 2  2022-01-15 00:03:06
# 3  2022-01-15 00:04:07
# 4  2022-01-15 00:05:08

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


sns.set_style("whitegrid", {"axes.facecolor": "#00000000", "figure.facecolor": "#00000000"})
sns.set_context("notebook", font_scale=1.5)


plt.plot((df['id']-4064995)/60, df['QNH'], linewidth = 0.6)

plt.xlabel("Zeit t")
plt.ylabel("QNH")
plt.show()

# %%
df = df[
    (df['createTime'] >= '2022-01-15 19:30:00') & 
    (df['createTime'] <= '2022-01-15 21:30:00')
]

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


sns.set_style("whitegrid", {"axes.facecolor": "#00000000", "figure.facecolor": "#00000000"})
sns.set_context("notebook", font_scale=1.5)


plt.scatter((df['id']-4066121)/60, df['QNH'], s = 3)

plt.xlabel("Zeit t")
plt.ylabel("QNH")
plt.show()

# %%
pd.set_option('display.max_rows', df.shape[0]+1)
df
# Out:
#            id station  temperature     QFE      QNH  dewpoint  ceiling  \
# 1126  4066121    EDNG        -1.03  963.79  1024.82     -1.03  1793.54
# 1127  4066122    EDNG        -1.01  963.71  1024.74     -1.01  1793.54
# 1128  4066123    EDNG        -1.00  963.68  1024.71     -1.00  1793.54
# 1129  4066124    EDNG        -0.99  963.65  1024.68     -0.99  1793.54
# 1130  4066125    EDNG        -0.98  963.68  1024.71     -0.98  1793.54
# 1131  4066126    EDNG        -0.97  963.65  1024.68     -0.97  1793.54
# 1132  4066127    EDNG        -0.97  963.70  1024.73     -0.97  1793.54
# 1133  4066128    EDNG        -0.96  963.67  1024.70     -0.96  1793.54
# 1134  4066129    EDNG        -0.95  963.63  1024.66     -0.95  1793.54
# 1135  4066130    EDNG        -0.95  963.63  1024.66     -0.95  1793.54
# 1136  4066131    EDNG        -0.95  963.63  1024.66     -0.95  1793.54
# 1137  4066132    EDNG        -0.95  963.59  1024.61     -0.95  1793.54
# ...

# %%
df['dateTimeIndex'] = pd.DatetimeIndex(df['createTime'])

# %%
for d in df['dateTimeIndex']:
    print(d.hour*60+d.minute)
# Out:
# 1172
# 1173
# 1174
# 1176
# 1177
# 1178
# 1179
# 1180
# 1181
# 1182
# 1183
# 1184
# 1185
# 1186
# 1187
# 1188
# 1189
# 1190
# 1191
# 1192
# 1193
# 1194
# 1195
# 1196
# 1197
# 1198
# 1199
# 1200
# 1201
# 1202
# 1203
# 1204
# 1205
# 1206
# 1207
# 1208
# 1209
# 1210
# 1211
# 1212
# 1213
# 1214
# 1215
# 1216
# 1217
# 1218
# 1219
# 1220
# 1221
# 1222
# 1223
# 1224
# 1226
# 1227
# 1228
# 1229
# 1230
# 1231
# 1232
# 1233
# 1234
# 1235
# 1236
# 1237
# 1238
# 1239
# 1240
# 1241
# 1242
# 1243
# 1244
# 1245
# 1246
# 1247
# 1248
# 1249
# 1250
# 1251
# 1252
# 1253
# 1254
# 1255
# 1256
# 1257
# 1258
# 1259
# 1260
# 1261
# 1262
# 1263
# 1264
# 1265
# 1266
# 1267
# 1268
# 1269
# 1270
# 1271
# 1272
# 1274
# 1275
# 1276
# 1277
# 1278
# 1279
# 1280
# 1281
# 1282
# 1283
# 1284
# 1285
# 1286
# 1287
# 1288
# 1289
