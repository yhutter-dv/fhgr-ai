# %% [markdown]
# # 0. Installation und Abhängigkeiten

# %%
# !pip3 install --upgrade pip --user
# Out:
# Requirement already satisfied: pip in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (22.2.2)
# Collecting pip
#   Downloading pip-23.0.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 6.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pip
#   WARNING: The scripts pip, pip3 and pip3.9 are installed in '/Users/assfalg/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed pip-23.0.1

# %%
# !pip install swig --user
# Out:
# Collecting swig
#   Using cached swig-4.1.1-py2.py3-none-macosx_10_9_x86_64.whl (1.7 MB)
# Installing collected packages: swig
#   WARNING: The script swig is installed in '/Users/assfalg/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed swig-4.1.1

# %%
# !pip install stable_baselines3 --user
# Out:
# Requirement already satisfied: stable_baselines3 in /Users/assfalg/.local/lib/python3.9/site-packages (1.7.0)
# Requirement already satisfied: gym==0.21 in /Users/assfalg/.local/lib/python3.9/site-packages (from stable_baselines3) (0.21.0)
# Requirement already satisfied: numpy in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from stable_baselines3) (1.20.3)
# Requirement already satisfied: torch>=1.11 in /Users/assfalg/.local/lib/python3.9/site-packages (from stable_baselines3) (2.0.0)
# Requirement already satisfied: cloudpickle in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from stable_baselines3) (2.0.0)
# Requirement already satisfied: pandas in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from stable_baselines3) (1.4.4)
# Requirement already satisfied: matplotlib in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from stable_baselines3) (3.5.2)
# Requirement already satisfied: importlib-metadata~=4.13 in /Users/assfalg/.local/lib/python3.9/site-packages (from stable_baselines3) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata~=4.13->stable_baselines3) (3.8.0)
# Requirement already satisfied: filelock in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable_baselines3) (3.6.0)
# Requirement already satisfied: typing-extensions in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable_baselines3) (4.8.0)
# Requirement already satisfied: sympy in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable_baselines3) (1.10.1)
# Requirement already satisfied: networkx in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable_baselines3) (2.8.4)
# Requirement already satisfied: jinja2 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11->stable_baselines3) (2.11.3)
# Requirement already satisfied: cycler>=0.10 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from pandas->stable_baselines3) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.11->stable_baselines3) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.11->stable_baselines3) (1.2.1)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (2.12.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: setuptools in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (67.6.1)
# Requirement already satisfied: packaging in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: six>=1.12.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (4.22.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: jax>=0.3.15 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.4.8)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.53.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow) (1.9.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from jax>=0.3.15->tensorflow) (0.0.4)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.11)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)

# %%
# !pip3 install gym
# Out:
# Requirement already satisfied: gym in /Users/assfalg/.local/lib/python3.9/site-packages (0.21.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from gym) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (from gym) (1.23.5)

# %%
# !pip3 install cmake --user
# Out:
# Requirement already satisfied: cmake in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (3.26.1)

# %%
# !pip3 install swig
# Out:
# Requirement already satisfied: swig in /Users/assfalg/.local/lib/python3.9/site-packages (4.1.1)

# %%
# !pip install wheel --upgrade
# Out:
# Requirement already satisfied: wheel in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (0.40.0)

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/assfalg/.local/lib/python3.9/site-packages (23.0.1)

# %%
# !pip install box2d-py --upgrade
# Out:
# Collecting box2d-py
#   Using cached box2d-py-2.3.8.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp39-cp39-macosx_10_9_x86_64.whl size=405782 sha256=17cd62f2a42805a23ad50b6f3fdc798d02257393b9010d55593e05b4df1d3f97
#   Stored in directory: /Users/assfalg/Library/Caches/pip/wheels/a0/6a/54/2383a12859109612796c6b235ff6704a82b99caa4308ca0b43
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8

# %%
# !pip install pypybox2d --upgrade
# Out:
# Requirement already satisfied: pypybox2d in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (2.1.post331)

# %%
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (2.3.0)

# %%
# !pip install pyglet==1.5.27
# Out:
# Collecting pyglet==1.5.27
#   Downloading pyglet-1.5.27-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pyglet
#   Attempting uninstall: pyglet
#     Found existing installation: pyglet 2.0.5
#     Uninstalling pyglet-2.0.5:
#       Successfully uninstalled pyglet-2.0.5
# Successfully installed pyglet-1.5.27

# %%
import sys
sys.path
# Out:
# ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python39.zip',
#  '/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9',
#  '/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/lib-dynload',
#  '',
#  '/Users/yhutter/GitRepos/fhgr-ai/code/venv/lib/python3.9/site-packages']

# %%
import gym

# %%
# !pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in /Users/assfalg/opt/anaconda3/lib/python3.9/site-packages (1.20.3)
# Collecting numpy
#   Downloading numpy-1.26.2-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 29.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.26.2 which is incompatible.
# scipy 1.9.1 requires numpy<1.25.0,>=1.18.5, but you have numpy 1.26.2 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.26.2 which is incompatible.
# Successfully installed numpy-1.26.2

# %%
#import stable_baselines3
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
# Out:
# /Users/yhutter/GitRepos/fhgr-ai/code/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # 1. Testen eines zufälligen Agenten in einem zufälligen Environment

# %%
import gym 
environment_name = 'LunarLander-v2'
env = gym.make(environment_name)

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# /Users/yhutter/GitRepos/fhgr-ai/code/venv/lib/python3.9/site-packages/gym/envs/box2d/lunar_lander.py:604: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("LunarLander-v2", render_mode="rgb_array")
#   gym.logger.warn(
# /Users/yhutter/GitRepos/fhgr-ai/code/venv/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 10
#       8     env.render()
#       9     action = env.action_space.sample()
# ---> 10     n_state, reward, done, info = env.step(action)
#      11     score+=reward
#      12 print('Episode:{} Score:{}'.format(episode, score))
#
# ValueError: too many values to unpack (expected 4)

# %% [markdown]
# # 2. Erstellen und Trainieren eines Modells

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
# MlpPolicy steht für Multilayer Perceptron (2 layers of 64)
# MlpLstmPolicy Long Short-Term Memory (LSTM) mit einem  Multilayer Percepron feature extraction
#... usw. siehe: https://stable-baselines.readthedocs.io/en/master/modules/policies.html
model = PPO('MlpPolicy', env, verbose = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/lp/k8dy9zk91tlbkfkpvlds522m0000gn/T/ipykernel_48217/2959309501.py in <module>
# ----> 1 env = gym.make(environment_name)
#       2 env = DummyVecEnv([lambda: env])
#       3 # MlpPolicy steht für Multilayer Perceptron (2 layers of 64)
#       4 # MlpLstmPolicy Long Short-Term Memory (LSTM) mit einem  Multilayer Percepron feature extraction
#       5 #... usw. siehe: https://stable-baselines.readthedocs.io/en/master/modules/policies.html
#
# NameError: name 'environment_name' is not defined

# %%
model.learn(total_timesteps=200000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1780 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1222       |
# |    iterations           | 2          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00900768 |
# |    clip_fraction        | 0.025      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | -0.00296   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 580        |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.00653   |
# |    value_loss           | 1.27e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1125        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004531274 |
# |    clip_fraction        | 0.0116      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0243     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 274         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00669    |
# |    value_loss           | 989         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1077        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008637331 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0186     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 290         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00947    |
# |    value_loss           | 868         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1053        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010061294 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0362     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 297         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 667         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1032        |
# |    iterations           | 6           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008089503 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.00215    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 414         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00772    |
# |    value_loss           | 706         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1018        |
# |    iterations           | 7           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010437844 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.00102    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 208         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00836    |
# |    value_loss           | 381         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1011        |
# |    iterations           | 8           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009355374 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00104    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 373         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00532    |
# |    value_loss           | 545         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1001       |
# |    iterations           | 9          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01200384 |
# |    clip_fraction        | 0.122      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | -4.02e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 108        |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0143    |
# |    value_loss           | 266        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 995         |
# |    iterations           | 10          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.004123017 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.000402   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 353         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00147    |
# |    value_loss           | 692         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 990         |
# |    iterations           | 11          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013698833 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.000424   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 110         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00805    |
# |    value_loss           | 304         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 982         |
# |    iterations           | 12          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008656124 |
# |    clip_fraction        | 0.0283      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.019       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 74.2        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00677    |
# |    value_loss           | 271         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 978          |
# |    iterations           | 13           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0044418275 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.0469       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 237          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00527     |
# |    value_loss           | 390          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 973          |
# |    iterations           | 14           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0050928537 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 175          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00585     |
# |    value_loss           | 304          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 950         |
# |    iterations           | 15          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014542233 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.31        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 87.9        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 190         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 946         |
# |    iterations           | 16          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.003424596 |
# |    clip_fraction        | 0.00566     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 101         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00243    |
# |    value_loss           | 197         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 942        |
# |    iterations           | 17         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00211658 |
# |    clip_fraction        | 0.004      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | 0.195      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 87.2       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00225   |
# |    value_loss           | 234        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 939         |
# |    iterations           | 18          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005736663 |
# |    clip_fraction        | 0.014       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 107         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0061     |
# |    value_loss           | 186         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 927         |
# |    iterations           | 19          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008862116 |
# |    clip_fraction        | 0.0596      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.349       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.2        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00726    |
# |    value_loss           | 187         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 922         |
# |    iterations           | 20          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010201199 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.6        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00651    |
# |    value_loss           | 95.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 905         |
# |    iterations           | 21          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008619373 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.7        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00896    |
# |    value_loss           | 172         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 22          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010884436 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.588       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 81.7        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00695    |
# |    value_loss           | 173         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 897         |
# |    iterations           | 23          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004450719 |
# |    clip_fraction        | 0.0178      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55          |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00425    |
# |    value_loss           | 120         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 891          |
# |    iterations           | 24           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0063972874 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.651        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.9         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00564     |
# |    value_loss           | 121          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 25          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008108511 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.7        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00724    |
# |    value_loss           | 111         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 26          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.007649309 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32          |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00711    |
# |    value_loss           | 125         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 27          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009960998 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0057     |
# |    value_loss           | 44.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 28          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009085215 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64.2        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00803    |
# |    value_loss           | 73.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 828         |
# |    iterations           | 29          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011642911 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.7        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00847    |
# |    value_loss           | 72.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 30          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008192279 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.37        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00677    |
# |    value_loss           | 44.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 799         |
# |    iterations           | 31          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008904437 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.1        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0078     |
# |    value_loss           | 42          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 788         |
# |    iterations           | 32          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011039307 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00918    |
# |    value_loss           | 53.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 777         |
# |    iterations           | 33          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008003905 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.7        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 60.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 34          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.010192415 |
# |    clip_fraction        | 0.0991      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.972      |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.87        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 17          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 35          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008889653 |
# |    clip_fraction        | 0.0445      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.959      |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.4        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00506    |
# |    value_loss           | 80          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 763          |
# |    iterations           | 36           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0065325163 |
# |    clip_fraction        | 0.0527       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.908       |
# |    explained_variance   | 0.72         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.6         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00296     |
# |    value_loss           | 57.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 754         |
# |    iterations           | 37          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011370939 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.42        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00958    |
# |    value_loss           | 18.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 746          |
# |    iterations           | 38           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0029782534 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.908       |
# |    explained_variance   | 0.734        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.6         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 64.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 39          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.019653354 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.43        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00824    |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 40          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010810585 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00795    |
# |    value_loss           | 66.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 41           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0066299704 |
# |    clip_fraction        | 0.0783       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.814       |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.01         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 11.4         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 42          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.005742556 |
# |    clip_fraction        | 0.092       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.879      |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00541    |
# |    value_loss           | 54.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 43          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005367988 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.4        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 57.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 44          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006376136 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.831      |
# |    explained_variance   | 0.624       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00435    |
# |    value_loss           | 148         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 45          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.009995462 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.4        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00727    |
# |    value_loss           | 181         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 712          |
# |    iterations           | 46           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0030967218 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.927       |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 97.6         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00281     |
# |    value_loss           | 162          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 712          |
# |    iterations           | 47           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0066589927 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | 0.582        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 121          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 168          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 709          |
# |    iterations           | 48           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0028500045 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.895       |
# |    explained_variance   | 0.542        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.4         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 150          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 49          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.008656053 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.6        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00336    |
# |    value_loss           | 91.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 701          |
# |    iterations           | 50           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0041588955 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.87        |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12           |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 153          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 701         |
# |    iterations           | 51          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.007786469 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.811      |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.5        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 186         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 701          |
# |    iterations           | 52           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0039144927 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.927       |
# |    explained_variance   | 0.373        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.1         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 173          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 702          |
# |    iterations           | 53           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0052582226 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.872       |
# |    explained_variance   | 0.568        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 183          |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 253          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 702          |
# |    iterations           | 54           |
# |    time_elapsed         | 157          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0068496717 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | 0.501        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 92.2         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00449     |
# |    value_loss           | 208          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 55          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.005071131 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.727      |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 108         |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.004      |
# |    value_loss           | 200         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 56          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.005978455 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.8        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00332    |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 57          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.005479412 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.866      |
# |    explained_variance   | 0.52        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.4        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 167         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 58          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.008439736 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.2        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00331    |
# |    value_loss           | 152         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 698          |
# |    iterations           | 59           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0040863883 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.882       |
# |    explained_variance   | 0.471        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.1         |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 168          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 698          |
# |    iterations           | 60           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0057416554 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.833       |
# |    explained_variance   | 0.45         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.7         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00318     |
# |    value_loss           | 59.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 61          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.004915429 |
# |    clip_fraction        | 0.0795      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.226       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 91.8        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00472    |
# |    value_loss           | 190         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 62          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.003909719 |
# |    clip_fraction        | 0.0325      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.73       |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.4        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00122    |
# |    value_loss           | 78.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 63          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.006786015 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 79.8        |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00688    |
# |    value_loss           | 198         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 697         |
# |    iterations           | 64          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.004532683 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.539       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.5        |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00308    |
# ...
# |    iterations           | 78           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0045483033 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.781       |
# |    explained_variance   | 0.312        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.6         |
# |    n_updates            | 770          |
# |    policy_gradient_loss | -0.00517     |
# |    value_loss           | 259          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 79          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 161792      |
# | train/                  |             |
# |    approx_kl            | 0.004875195 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.79       |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.8        |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.00235    |
# |    value_loss           | 48.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 705          |
# |    iterations           | 80           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0032667518 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.791       |
# |    explained_variance   | 0.568        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.7         |
# |    n_updates            | 790          |
# |    policy_gradient_loss | -0.000745    |
# |    value_loss           | 134          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 705        |
# |    iterations           | 81         |
# |    time_elapsed         | 234        |
# |    total_timesteps      | 165888     |
# | train/                  |            |
# |    approx_kl            | 0.00673903 |
# |    clip_fraction        | 0.0606     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.781     |
# |    explained_variance   | 0.861      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.1       |
# |    n_updates            | 800        |
# |    policy_gradient_loss | -0.00129   |
# |    value_loss           | 31         |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 706          |
# |    iterations           | 82           |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0103003215 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.781       |
# |    explained_variance   | 0.772        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.42         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00321     |
# |    value_loss           | 43           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 83           |
# |    time_elapsed         | 240          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0054545095 |
# |    clip_fraction        | 0.047        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.717       |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.2         |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00305     |
# |    value_loss           | 38.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 708          |
# |    iterations           | 84           |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0024095662 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.615       |
# |    explained_variance   | 0.691        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.1         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 52.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 85          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.004813716 |
# |    clip_fraction        | 0.0483      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | 3.03e-05    |
# |    value_loss           | 19.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 710          |
# |    iterations           | 86           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0025281943 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.787       |
# |    explained_variance   | 0.562        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.92         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 107          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 711          |
# |    iterations           | 87           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0033103204 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.718       |
# |    explained_variance   | 0.438        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.2         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 167          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 712          |
# |    iterations           | 88           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0036569966 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.808       |
# |    explained_variance   | 0.486        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.4         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.00371     |
# |    value_loss           | 191          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 89          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.005921465 |
# |    clip_fraction        | 0.0388      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.777      |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.9        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0015     |
# |    value_loss           | 151         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 90          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.010259723 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.712      |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.75        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00483    |
# |    value_loss           | 48.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 91          |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.008101821 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.778      |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 155         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 715          |
# |    iterations           | 92           |
# |    time_elapsed         | 263          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0046207276 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.734       |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 81.8         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00414     |
# |    value_loss           | 164          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 716          |
# |    iterations           | 93           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0037570205 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | 0.417        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.7         |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.0032      |
# |    value_loss           | 195          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 94           |
# |    time_elapsed         | 268          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0033093872 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.728       |
# |    explained_variance   | 0.598        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 128          |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 165          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 95           |
# |    time_elapsed         | 270          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0056485836 |
# |    clip_fraction        | 0.0613       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.581       |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 76.1         |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.00381     |
# |    value_loss           | 89.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 719          |
# |    iterations           | 96           |
# |    time_elapsed         | 273          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0055236956 |
# |    clip_fraction        | 0.0612       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.712       |
# |    explained_variance   | 0.726        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.4         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 45.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 97          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.007929556 |
# |    clip_fraction        | 0.0728      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 24.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 98           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0027176253 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.758       |
# |    explained_variance   | 0.294        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43           |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.000863    |
# |    value_loss           | 290          |
# ------------------------------------------

# %% [markdown]
# # 3. Testen, Speichern und Laden des trainierten Modells

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
env.close()
# Out:
# C:\Users\ra\AppData\Roaming\Python\Python38\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
model.save("PPO_model")

# %%
del model

# %%
model = PPO.load("PPO_model", env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
env.close()
# Out:
# /Users/assfalg/.local/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# 2024-02-16 00:30:39.730 python[48217:5174447] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7f866e799410>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-02-16 00:30:39.731 python[48217:5174447] Warning: Expected min height of view: (<NSButton: 0x7f866f91a980>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-02-16 00:30:39.734 python[48217:5174447] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7f866e7a5c20>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-02-16 00:30:39.735 python[48217:5174447] Warning: Expected min height of view: (<NSPopoverTouchBarItemButton: 0x7f867fdb91d0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.

# %%
#Andere Methode der Evaluation als Endlosschleife für Dauerdemos
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
